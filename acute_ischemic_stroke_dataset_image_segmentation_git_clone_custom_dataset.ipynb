# %%
# !git clone https://github.com/Herutriana44/Acute-ischemic-stroke-dataset-image-segmentation
# Out:
# Cloning into 'Acute-ischemic-stroke-dataset-image-segmentation'...
# remote: Enumerating objects: 884, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 884 (delta 70), reused 72 (delta 63), pack-reused 797 (from 1)
# Receiving objects: 100% (884/884), 195.76 MiB | 27.37 MiB/s, done.
# Resolving deltas: 100% (448/448), done.
# Updating files: 100% (157/157), done.

# %%
# %cd Acute-ischemic-stroke-dataset-image-segmentation
# Out:
# /content/Acute-ischemic-stroke-dataset-image-segmentation

# %%
# !mkdir dataset

# %% [markdown]
# ## Dataset dari mega
#
# https://mega.nz/folder/RThSyIhC#e3kBIKBTM728iIeceG5hlQ
#
# ini dalam bentuk folder

# %%
# !pip install mega.py -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 25.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotly 5.24.1 requires tenacity>=6.2.0, but you have tenacity 5.1.5 which is incompatible.
# pyiceberg 0.11.1 requires tenacity<10.0.0,>=8.2.3, but you have tenacity 5.1.5 which is incompatible.
# google-genai 1.68.0 requires tenacity<9.2.0,>=8.2.3, but you have tenacity 5.1.5 which is incompatible.
# google-adk 1.29.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 5.1.5 which is incompatible.
# langchain-core 1.4.0 requires tenacity!=8.4.0,<10.0.0,>=8.1.0, but you have tenacity 5.1.5 which is incompatible.

# %%
# !pip install tenacity>=5.1.5 --upgrade
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mega-py 1.0.8 requires tenacity<6.0.0,>=5.1.5, but you have tenacity 9.1.4 which is incompatible.

# %%
from mega import Mega
import os

from mega import Mega
mega = Mega()
m = mega.login()

file_url = "https://mega.nz/file/QDATCRLZ#3U76anhsjjo44UMXu5ILneDi0CJjolAZp6SDz9BHaLU"
file_id = file_url.split('/')[-1].split('#')[0]
downloaded_file = m.download_url(file_url)
print(f"File downloaded to: {downloaded_file}")


file_url = "https://mega.nz/file/QDATCRLZ#3U76anhsjjo44UMXu5ILneDi0CJjolAZp6SDz9BHaLU"
file_id = file_url.split('/')[-1].split('#')[0]
downloaded_file = m.download_url(file_url)
print(f"File downloaded to: {downloaded_file}")
# Out:
# File downloaded to: drive-download-20260527T123924Z-3-001.zip
# File downloaded to: drive-download-20260527T123924Z-3-001.zip

# %%
# !unzip drive-download-20260527T123924Z-3-001.zip
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
#   inflating: yolo_dataset5/labels/train/0538479_041.txt
#   inflating: yolo_dataset5/labels/train/0538479_008.txt
#   inflating: yolo_dataset5/labels/train/0538479_036.txt
#   inflating: yolo_dataset5/labels/train/0538479_010.txt
#   inflating: yolo_dataset5/labels/train/0091419_022.txt
#   inflating: yolo_dataset5/labels/train/0538479_015.txt
#   inflating: yolo_dataset5/labels/train/0091419_027.txt
#   inflating: yolo_dataset5/labels/train/0091419_041.txt
#   inflating: yolo_dataset5/labels/train/0091419_023.txt
#   inflating: yolo_dataset5/labels/train/0538479_012.txt
#   inflating: yolo_dataset5/labels/train/0091419_026.txt
#   inflating: yolo_dataset5/labels/train/0091419_024.txt
#   inflating: yolo_dataset5/labels/train/0538479_021.txt
#   inflating: yolo_dataset5/labels/train/0091419_030.txt
#   inflating: yolo_dataset5/labels/train/0538479_022.txt
#   inflating: yolo_dataset5/labels/train/0538479_027.txt
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !mkdir new_model

# %%
# %%writefile retrain_unet.py
#!/usr/bin/env python3
"""Entry point: jalankan dari root proyek, mis. `python train_unet.py`."""

from unet_segmentation.retrain_yolo import main

if __name__ == "__main__":
    raise SystemExit(main())
# Out:
# Overwriting retrain_unet.py

# %%
# !python retrain_unet.py \
  --checkpoint ./best_unet.pt \
  --yolo-root ./FINAL_YOLO_STROKE_V3 \
  --epochs 1
# Out:
# /content/Acute-ischemic-stroke-dataset-image-segmentation/unet_segmentation/dataset.py:126: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(5.0, 40.0), p=0.2),
# Dataset Baru Terload. Train: 241, Val: 859
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# -> Memuat bobot pre-trained model dari: best_unet.pt
# ...

# %%
# !mv new_model/best_unet.pt best_unet_1.pt
# Out:
# mv: cannot stat 'new_model/best_unet.pt': No such file or directory
